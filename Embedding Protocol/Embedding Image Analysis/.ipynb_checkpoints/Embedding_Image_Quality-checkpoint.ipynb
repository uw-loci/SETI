# %% [markdown]
# # User Input

# %%
data_path = 'D:\LOCI\Embedding\t_data'
# data_path is the full path to the folder with all the data sets to be processed

ij_local_installation='D:\Fiji.app'
# ij_local_installation is the full path to your local FIJI install with FLIMJ

# %% [markdown]
# # Dependencies

# %%
from pathlib import Path
import numpy as np
import zipfile
import matplotlib.pyplot as plt
import imagej

# %% [markdown]
# # File Discovery

# %%
data_path = Path(data_path)

# Find Number of Data Sets


# Get the Data Set Names


# Need to differentiate pollen grain sample vs. Structure being tested


# List of files per data set 


# Initialize ImageJ Instance
ij = imagej.init(ij_local_installation,headless=True)

# %% [markdown]
# # Mean Fluorescence Intensity Comparison and Image Quality Analysis

# %%
# Iterate across all data sets



# Load Data Set



# Mean Fluorescence Intensity Comparison



# Image Quality Analysis



# Remove Data Set From Memory Once Finished

# %% [markdown]
# # Results

# %%
# Plot Mean Results with Std Dev Bars and Labels Scrounged from Folder Titles

plt.figure(figsize=[10,3])

plt.subplot(131)
plt.imshow(paramMap[0],vmin=paramMap[0].mean())
plt.colorbar()
plt.title('Z (Background/Offset)')

plt.subplot(132)
plt.imshow(paramMap[1],vmax=paramMap[1].mean()*5)
plt.colorbar()
plt.title('A (Amplitude)')

plt.subplot(133)
plt.imshow(paramMap[2],vmax=paramMap[2].mean()*2,vmin=0.5)
plt.colorbar()
plt.title('τ / Lifetime(ns)')

plt.tight_layout()

# %% [markdown]
# ### Close the JVM ImageJ Instance

# %%
ij.dispose()
